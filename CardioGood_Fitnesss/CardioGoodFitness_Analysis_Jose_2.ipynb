# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CardioGoodFitness.csv')
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df_age = df.groupby(by='Age')
df_age.head()
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# ..      ...  ...     ...        ...           ...    ...      ...     ...
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# 177   TM798   45    Male         16        Single      5        5   90886
# 178   TM798   47    Male         18     Partnered      4        5  104581
# 179   TM798   48    Male         18     Partnered      4        5   95508
#
#      Miles
# 0      112
# 1       75
# 2       66
# 3       85
# 4       47
# ...

# %%
df.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.Age.hist()
# Out:
# <AxesSubplot:>

# %%
df.Usage.hist()
# Out:
# <AxesSubplot:>

# %%
df_age = df.groupby(by='Product')['Age'].mean()
df_age
# Out:
# Product
# TM195    28.55
# TM498    28.90
# TM798    29.10
# Name: Age, dtype: float64

# %%
df_inc = df.groupby(by='Product')['Income'].mean()
df_inc
# Out:
# Product
# TM195    46418.025
# TM498    48973.650
# TM798    75441.575
# Name: Income, dtype: float64

# %%
df_ed = df.groupby(by='Product')['Education'].mean()
df_ed
# Out:
# Product
# TM195    15.037500
# TM498    15.116667
# TM798    17.325000
# Name: Education, dtype: float64

# %%
df_gender = df.groupby(by='Product')['Gender'].value_counts()
df_gender
# Out:
# Product  Gender
# TM195    Female    40
#          Male      40
# TM498    Male      31
#          Female    29
# TM798    Male      33
#          Female     7
# Name: Gender, dtype: int64

# %%
df_use_c = df.groupby(by='Product')['Usage'].value_counts()
df_use_c
# Out:
# Product  Usage
# TM195    3        37
#          4        22
#          2        19
#          5         2
# TM498    3        31
#          2        14
#          4        12
#          5         3
# TM798    4        18
#          5        12
#          6         7
#          7         2
#          3         1
# Name: Usage, dtype: int64

# %%
df_use = df.groupby(by='Product')['Usage'].mean()
df_use
# Out:
# Product
# TM195    3.087500
# TM498    3.066667
# TM798    4.775000
# Name: Usage, dtype: float64

# %%
df_miles = df.groupby(by='Product')['Miles'].mean()
df_miles
# Out:
# Product
# TM195     82.787500
# TM498     87.933333
# TM798    166.900000
# Name: Miles, dtype: float64

# %%
df_mar = df.groupby(by='Product')['MaritalStatus'].value_counts()
df_mar
# Out:
# Product  MaritalStatus
# TM195    Partnered        48
#          Single           32
# TM498    Partnered        36
#          Single           24
# TM798    Partnered        23
#          Single           17
# Name: MaritalStatus, dtype: int64

# %%
df_age = df.groupby(by='Product')['Age'].mean()
print('Product by mean age', df_age)
print(20*'_ ')
df_inc = df.groupby(by='Product')['Income'].mean()
print('Product by mean income',df_inc)
print(20*'_ ')
df_ed = df.groupby(by='Product')['Education'].mean()
print('Product by mean education',df_ed)
print(20*'_ ')
df_gender = df.groupby(by='Product')['Gender'].value_counts()
print('Product by gender',df_gender)
print(20*'_ ')
df_use_c = df.groupby(by='Product')['Usage'].value_counts()
print('Product by gym usage',df_use_c)
print(20*'_ ')
df_miles = df.groupby(by='Product')['Miles'].mean()
print('Product by distance',df_miles)
print(20*'_ ')
df_mar = df.groupby(by='Product')['MaritalStatus'].value_counts()
print('Product by marital status',df_mar)
print(20*'_ ')
df_fit = df.groupby(by='Product')['Fitness'].mean()
print('Product by fitness ratio',df_fit)
print(20*'_ ')
df_genfit = df.groupby(by='Gender')['Fitness'].value_counts()
print('Gender by fitness commitment',df_genfit)
print(20*'_ ')
# Out:
# Product by mean age Product
# TM195    28.55
# TM498    28.90
# TM798    29.10
# Name: Age, dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product by mean income Product
# TM195    46418.025
# TM498    48973.650
# TM798    75441.575
# Name: Income, dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product by mean education Product
# TM195    15.037500
# TM498    15.116667
# TM798    17.325000
# Name: Education, dtype: float64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product by gender Product  Gender
# TM195    Female    40
#          Male      40
# TM498    Male      31
#          Female    29
# TM798    Male      33
#          Female     7
# Name: Gender, dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product by gym usage Product  Usage
# TM195    3        37
#          4        22
#          2        19
#          5         2
# TM498    3        31
#          2        14
#          4        12
#          5         3
# TM798    4        18
# ...

# %%
# Fitness usage, income, gender, miles

# %%
df.groupby(by=['Product', 'Gender'])['Income'].mean()
# Out:
# Product  Gender
# TM195    Female    46020.075000
#          Male      46815.975000
# TM498    Female    49336.448276
#          Male      48634.258065
# TM798    Female    73633.857143
#          Male      75825.030303
# Name: Income, dtype: float64

# %%
df.groupby(by=['Product', 'Gender'])['Income'].value_counts()
# Out:
# Product  Gender  Income
# TM195    Female  46617     5
#                  35247     3
#                  45480     3
#                  52302     3
#                  34110     2
#                           ..
# TM798    Male    77191     1
#                  85906     1
#                  95508     1
#                  99601     1
#                  103336    1
# Name: Income, Length: 112, dtype: int64

# %%
df_fem = df[(df['Gender']=='Female') & (df['Income']>=60000)].count()
print(df_fem)
print(20*'_ ')
df_men = df[(df['Gender']=='Male') & (df['Income']>=60000)].count()
print(df_men)
# Out:
# Product          13
# Age              13
# Gender           13
# Education        13
# MaritalStatus    13
# Usage            13
# Fitness          13
# Income           13
# Miles            13
# dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product          29
# Age              29
# Gender           29
# Education        29
# MaritalStatus    29
# Usage            29
# Fitness          29
# Income           29
# Miles            29
# dtype: int64

# %%
df_inc.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product'>

# %%
df_genfit.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender,Fitness'>

# %%
sns.boxplot(x='Product', y='Income', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Income'>

# %%
sns.violinplot(x='Product', y='Fitness', hue='Gender', data=df)
# People how buy the most expensive exercise more times a week
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Fitness'>

# %%
sns.violinplot(x='Product', y='Education', hue='Gender', data=df)
# Education seems irrelevant for this analysis
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Education'>

# %%
sns.violinplot(x='Product', y='Usage', hue='Gender', data=df)
# THERE ARE SOME PEOPLE BUYING THE BASIC ONE BUT USING IT NEARLY AS OFTEN AS PEOPLE THAT BUY THE EXPENSIVE ONE. THEREFORE,
# THOSE COULD BE A MARKET FOR THE EXPENSIVE ONE AS WELL
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Usage'>

# %%
sns.violinplot(x='Product', y='Miles', hue='Gender', data=df)
# People how buy the most expensive, use it mre often (usage) and therefore run more miles with it.
# There are always a small percentage of people using the others TM that do same amount of miles per week
# Out:
# <AxesSubplot:xlabel='Product', ylabel='Miles'>

# %%
# How many people earning less than 60k run more than 150miles per week? Here we assume those buy the 2 cheaper options
df_fem = df[(df['Gender']=='Female') & (df['Income']<=60000) & (df['Miles']>150)].count()
print(df_fem)
print(20*'_ ')
df_men = df[(df['Gender']=='Male') & (df['Income']<=60000) & (df['Miles']>150)].count()
print(df_men)
# Out:
# Product          3
# Age              3
# Gender           3
# Education        3
# MaritalStatus    3
# Usage            3
# Fitness          3
# Income           3
# Miles            3
# dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product          6
# Age              6
# Gender           6
# Education        6
# MaritalStatus    6
# Usage            6
# Fitness          6
# Income           6
# Miles            6
# dtype: int64

# %%
#print(df['state'].isin(['NY', 'TX']))
product = ['TM195', 'TM498']
df_cheap = df[df['Product'].isin(product)]
df_cheap.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
# how many people that bought the 2 cheaper options and their income is less than 60k run more than 150 miles
#those could be potential buyers for the most expensive option
df_fem = df_cheap[(df_cheap['Gender']=='Female') & (df_cheap['Income']<=60000) & (df_cheap['Miles']>150)].count()
print(df_fem)
print(20*'_ ')
df_men = df_cheap[(df_cheap['Gender']=='Male') & (df_cheap['Income']<=60000) & (df_cheap['Miles']>150)].count()
print(df_men)
# Out:
# Product          2
# Age              2
# Gender           2
# Education        2
# MaritalStatus    2
# Usage            2
# Fitness          2
# Income           2
# Miles            2
# dtype: int64
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# Product          3
# Age              3
# Gender           3
# Education        3
# MaritalStatus    3
# Usage            3
# Fitness          3
# Income           3
# Miles            3
# dtype: int64

# %%
sns.violinplot(x='Usage', y='Miles', hue='Gender', data=df)
# Out:
# <AxesSubplot:xlabel='Usage', ylabel='Miles'>
