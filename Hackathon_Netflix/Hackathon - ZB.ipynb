# %%
import numpy as np
import seaborn as sns
import pandas as pd

df = pd.read_csv("data/static_csv.xls")


df
# Out:
#       Unnamed: 0 show_id     type                  title         director  \
# 0              0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1              1      s2  TV Show          Blood & Water              NaN
# 2              2      s3  TV Show              Ganglands  Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans              NaN
# 4              4      s5  TV Show           Kota Factory     Raghav Subbu
# ...          ...     ...      ...                    ...              ...
# 8802        8802   s8803    Movie                 Zodiac    David Fincher
# 8803        8803   s8804  TV Show            Zombie Dumb              NaN
# 8804        8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805        8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806        8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     8807 non-null   int64
#  1   show_id        8807 non-null   object
#  2   type           8807 non-null   object
#  3   title          8807 non-null   object
#  4   director       6925 non-null   object
#  5   cast           8675 non-null   object
#  6   country        8089 non-null   object
#  7   date_added     8797 non-null   object
#  8   release_year   8807 non-null   int64
#  9   rating         8803 non-null   object
#  10  release_month  8797 non-null   float64
#  11  duration       8804 non-null   object
#  12  audience       8803 non-null   object
#  13  listed_in      8807 non-null   object
#  14  description    8807 non-null   object
# dtypes: float64(1), int64(2), object(12)
# memory usage: 1.0+ MB

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0          0
# show_id             0
# type                0
# title               0
# director         1882
# cast              132
# country           718
# date_added         10
# release_year        0
# rating              4
# release_month      10
# duration            3
# audience            4
# listed_in           0
# description         0
# dtype: int64

# %%
df.describe()
# Out:
#         Unnamed: 0  release_year  release_month
# count  8807.000000   8807.000000    8797.000000
# mean   4403.000000   2014.190757       6.654996
# std    2542.506244      8.768048       3.436554
# min       0.000000   1942.000000       1.000000
# 25%    2201.500000   2013.000000       4.000000
# 50%    4403.000000   2017.000000       7.000000
# 75%    6604.500000   2019.000000      10.000000
# max    8806.000000   2021.000000      12.000000

# %%
df.describe(include=['O'])
# Out:
#        show_id   type                 title       director  \
# count     8807   8807                  8807           6925
# unique    8807      2                  8807           5082
# top         s1  Movie  Dick Johnson Is Dead  Rajiv Chilaka
# freq         1   6131                     1             21
#
#                       cast        country  date_added rating  duration  \
# count                 8675           8089        8797   8803      8804
# unique                8376            750        1714     14       220
# top     David Attenborough  United States  2020-01-01  TV-MA  1 Season
# freq                    19           2862         110   3210      1793
#
#        audience                     listed_in  \
# count      8803                          8807
# unique        4                           514
# top      Adults  Dramas, International Movies
# freq       4012                           362
#
#                                               description
# ...

# %%
top_10_countries = df['country'].value_counts().head(10)
top_10_countries_df = top_10_countries.reset_index(name = 'total')
top_10_countries_df
# Out:
#             index  total
# 0   United States   2862
# 1           India    993
# 2  United Kingdom    421
# 3           Japan    248
# 4     South Korea    214
# 5          Canada    181
# 6           Spain    146
# 7          France    129
# 8          Mexico    110
# 9           Egypt    106

# %%
movies = df[(df['type']=='Movie') & df['duration'].notnull()]
movies

#new df where type is movies and duration is not null
# Out:
#       Unnamed: 0 show_id   type                             title  \
# 0              0      s1  Movie              Dick Johnson Is Dead
# 6              6      s7  Movie  My Little Pony: A New Generation
# 7              7      s8  Movie                           Sankofa
# 9              9     s10  Movie                      The Starling
# 12            12     s13  Movie                      Je Suis Karl
# ...          ...     ...    ...                               ...
# 8801        8801   s8802  Movie                           Zinzana
# 8802        8802   s8803  Movie                            Zodiac
# 8804        8804   s8805  Movie                        Zombieland
# 8805        8805   s8806  Movie                              Zoom
# 8806        8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...

# %%
remove_word = 'min'
movies['duration'] = movies['duration'].str.replace(remove_word, '')
movies['duration'] = movies['duration'].astype(int)
movies

#removed 'min' from the end of the duration values and converted to int
# Out:
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#       Unnamed: 0 show_id   type                             title  \
# 0              0      s1  Movie              Dick Johnson Is Dead
# ...

# %%
movies.info()
#duration has been converted to int for movies df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6128 entries, 0 to 8806
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     6128 non-null   int64
#  1   show_id        6128 non-null   object
#  2   type           6128 non-null   object
#  3   title          6128 non-null   object
#  4   director       6059 non-null   object
#  5   cast           6044 non-null   object
#  6   country        5704 non-null   object
#  7   date_added     6128 non-null   datetime64[ns]
#  8   release_year   6128 non-null   int64
#  9   rating         6126 non-null   object
#  10  release_month  6128 non-null   float64
#  11  duration       6128 non-null   int64
#  12  audience       6126 non-null   object
#  13  listed_in      6128 non-null   object
#  14  description    6128 non-null   object
#  15  added_month    6128 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(10)
# ...

# %%
sorted_movies = movies.sort_values(by='duration')
sorted_movies.tail()
# Out:
#       Unnamed: 0 show_id   type                        title  \
# 2484        2484   s2485  Movie           Lock Your Girls In
# 2487        2487   s2488  Movie               No Longer kids
# 2491        2491   s2492  Movie       The School of Mischief
# 717          717    s718  Movie  Headspace: Unwind Your Mind
# 4253        4253   s4254  Movie   Black Mirror: Bandersnatch
#
#                     director  \
# 2484       Fouad El-Mohandes
# 2487         Samir Al Asfory
# 2491  Houssam El-Din Mustafa
# 717                      NaN
# 4253             David Slade
#
#                                                    cast        country  \
# 2484  Fouad El-Mohandes, Sanaa Younes, Sherihan, Ahm...            NaN
# 2487  Said Saleh, Hassan Moustafa, Ahmed Zaki, Youne...          Egypt
# 2491  Suhair El-Babili, Adel Emam, Saeed Saleh, Youn...          Egypt
# 717   Andy Puddicombe, Evelyn Lewis Prieto, Ginger D...            NaN
# ...

# %%
plt.figure(figsize=(14, 8))
sns.swarmplot(x='release_year', y='duration', data=movies, palette='magma')
plt.title('Swarm Plot of Movie Durations Over Release Years')
plt.xlabel('Release Year')
plt.ylabel('Duration (minutes)')
plt.xticks(rotation=90)
plt.show()
# Out:
# /kas/legacy/kate_python_37/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /kas/legacy/kate_python_37/site-packages/seaborn/categorical.py:1296: UserWarning: 10.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /kas/legacy/kate_python_37/site-packages/seaborn/categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /kas/legacy/kate_python_37/site-packages/seaborn/categorical.py:1296: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
tv_df = df[(df['type']=='TV Show') & df['duration'].notnull()]
tv_df
#created df for tv shows where duration values are all populated
# Out:
#       Unnamed: 0 show_id     type                  title          director  \
# 1              1      s2  TV Show          Blood & Water               NaN
# 2              2      s3  TV Show              Ganglands   Julien Leclercq
# 3              3      s4  TV Show  Jailbirds New Orleans               NaN
# 4              4      s5  TV Show           Kota Factory      Raghav Subbu
# 5              5      s6  TV Show          Midnight Mass     Mike Flanagan
# ...          ...     ...      ...                    ...               ...
# 8795        8795   s8796  TV Show        Yu-Gi-Oh! Arc-V               NaN
# 8796        8796   s8797  TV Show             Yunus Emre               NaN
# 8797        8797   s8798  TV Show              Zak Storm  Philippe Guyenne
# 8800        8800   s8801  TV Show     Zindagi Gulzar Hai  Sultana Siddiqui
# 8803        8803   s8804  TV Show            Zombie Dumb               NaN
#
#                                                    cast  \
# ...

# %%
tv_d = set(tv_df['duration'])
tv_d
#check what strings come after the int value
# Out:
# {'1 Season',
#  '10 Seasons',
#  '11 Seasons',
#  '12 Seasons',
#  '13 Seasons',
#  '15 Seasons',
#  '17 Seasons',
#  '2 Seasons',
#  '3 Seasons',
#  '4 Seasons',
#  '5 Seasons',
#  '6 Seasons',
#  '7 Seasons',
#  '8 Seasons',
#  '9 Seasons'}

# %%
remove_word1 = 'Season'
remove_word2 = 'Seasons'
tv_df['duration'] = tv_df['duration'].str.replace(remove_word2, '')
tv_df['duration'] = tv_df['duration'].str.replace(remove_word1, '')
tv_df['duration'] = tv_df['duration'].astype(int)
tv_df
# Out:
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /kas/kloud/notebook/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
# sns.scatterplot(data=df, y='type', x='audience', size="rating", hue = 'type', legend=True, sizes=(100, 100))
# plt.show()

# %%
count_rating = df['rating'].value_counts() 
count_rating
# Out:
# TV-MA       3210
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: rating, dtype: int64

# %% [markdown]
# # ***VISUALISATIONS BELOW vvvvv***

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.pie(df['type'].value_counts(), labels=df['type'].value_counts().index, autopct='%1.1f%%')
plt.title('Percentage of Movies vs TV Shows')
# Out:
# Text(0.5, 1.0, 'Percentage of Movies vs TV Shows')

# %%
sns.countplot(x = 'type', data = df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
plt.figure(figsize=(16, 8))
sns.countplot(x='country', data=movies, order=movies['country'].value_counts().head(10).index, palette='Set2')
plt.title('Top 10 Countries with Most Content')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
df['date_added'] = pd.to_datetime(df['date_added'], errors = 'coerce')
df['added_month'] = df['date_added'].dt.month
monthly_additions = df['added_month'].value_counts().sort_index()

plt.figure(figsize = (7, 6))
sns.barplot(x=monthly_additions.index, y = monthly_additions.values, palette = 'magma')
plt.title("Netflix's New Content every Month")
plt.xlabel('Month')
plt.ylabel('Number of Titles Added')
# Out:
# Text(0, 0.5, 'Number of Titles Added')

# %%
sns.lineplot(x = 'release_year', y = 'duration', data = movies)
plt.title("Movie duration per release year")
# Out:
# Text(0.5, 1.0, 'Movie duration per release year')

# %%
#A plot to show the movie duration per film year (just wanted to see the spread)
plt.figure(figsize = (20,5))
sns.boxplot(x = 'release_year', y = 'duration', data = movies)
plt.xticks(rotation=90)
plt.title('Boxplot of Movie Durations Over Release Years')
plt.xlabel('Release Year')
plt.ylabel('Duration (minutes)')


plt.show()

# %%
sns.histplot(data=df, x="type", hue="rating", multiple="stack")
# Out:
# <AxesSubplot:xlabel='type', ylabel='Count'>
